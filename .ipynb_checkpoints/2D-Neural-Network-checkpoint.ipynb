# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
class FourIndexLayer(nn.Module):
    def __init__(self, N):
        super().__init__()
        # Complex weights and biases
        self.W = nn.Parameter(torch.randn(N, N, N, N, dtype=torch.complex64) * 0.1)
        self.b = nn.Parameter(torch.zeros(N, N, dtype=torch.complex64))

    def forward(self, x):
        # x: [batch, N, N] complex
        ys = []
        for xx in x:  # xx: [N, N] complex
            # y_{ab} = sum_{cd} W_{abcd} * xx_{cd} + b_{ab}
            y = torch.einsum('abcd,cd->ab', self.W, xx) + self.b
            ys.append(y)
        return torch.stack(ys)

# %%
class MatrixNet(nn.Module):
    def __init__(self, N, depth=2):
        super().__init__()
        self.layers = nn.ModuleList([FourIndexLayer(N) for _ in range(depth)])

    def forward(self, x):
        # x: [batch, N, N] complex
        for layer in self.layers:
            x = torch.tanh(layer(x))
        return x  # output: [batch, N, N] complex

# %%
# Define fixed A and B for the target function
N = 4 
A = torch.randn(N, N, dtype=torch.complex64)
B = torch.randn(N, N, dtype=torch.complex64)
A, B
# Out:
# (tensor([[-0.4591-0.8874j, -0.9347+0.4067j,  0.4061-0.2787j,  0.2028+0.0753j],
#          [-0.7919+0.3138j,  0.4697+0.5658j,  0.3331-1.4096j,  1.2785+0.9156j],
#          [-0.7222-0.0715j, -0.6538+0.5740j, -0.6918-0.1572j, -0.6007-1.0417j],
#          [ 0.7095+0.4471j,  1.4944-0.4883j, -1.0572+1.6288j, -1.0047+0.0889j]]),
#  tensor([[ 0.0670+0.4124j, -0.5786+0.1294j, -0.6440+0.4003j, -0.9090-0.1403j],
#          [ 1.1844+1.0333j, -0.4221-0.3579j, -0.1858+0.1781j, -1.7636+0.6978j],
#          [-0.2372+0.2480j, -0.0765+0.3540j,  0.9234-0.6463j,  0.3441-0.9247j],
#          [-0.4913-0.8398j,  0.7986-0.0191j, -0.1865+1.2840j,  0.0644-1.4263j]]))

# %%
# Generate training data
training_size = 1000
X_train = []
Y_train = []
for _ in range(training_size):
    x = torch.randn(N, N, dtype=torch.complex64)
    y = torch.sin(torch.einsum('ij,jk->ik', A, x)) + torch.einsum('ij,jk->ik', A, x) + B  # Y = sin(AX) + AX + B
    X_train.append(x)
    Y_train.append(y)
X_train = torch.stack(X_train)
Y_train = torch.stack(Y_train)

# %%
# Instantiate and train the model
model = MatrixNet(N, depth=2)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.MSELoss()
model
# Out:
# MatrixNet(
#   (layers): ModuleList(
#     (0-1): 2 x FourIndexLayer()
#   )
# )

# %%
for epoch in range(501):
    optimizer.zero_grad()
    Y_pred = model(X_train)
    loss = loss_fn(Y_pred.real, Y_train.real) + loss_fn(Y_pred.imag, Y_train.imag)
    loss.backward()
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 180.68505859375
# Epoch 50, Loss: 180.515380859375
# Epoch 100, Loss: 180.34356689453125
# Epoch 150, Loss: 180.1610565185547
# Epoch 200, Loss: 179.96043395996094
# Epoch 250, Loss: 179.733642578125
# Epoch 300, Loss: 179.46798706054688
# Epoch 350, Loss: 179.11500549316406
# Epoch 400, Loss: 179.01133728027344
# Epoch 450, Loss: 178.833740234375
# Epoch 500, Loss: 178.65493774414062

# %%
# Example prediction
X_test = torch.randn(N, N, dtype=torch.complex64)
Y_test = torch.sin(torch.einsum('ij,jk->ik', A, X_test)) + B
Y_test_pred = model(X_test.unsqueeze(0))[0]
(Y_test_pred - Y_test)
# Out:
# tensor([[-2.6375e+00-4.2627e+00j,  7.5913e+00-1.4685e+01j,
#           3.8257e-01-1.1142e+00j,  1.2510e+00+3.8510e-01j],
#         [-4.1703e-01-6.8321e-01j, -5.2154e+01+1.1403e+01j,
#           5.7067e-01-8.6127e-01j,  3.7325e+00+1.1352e+00j],
#         [-3.4996e-01-4.7947e-01j,  1.1407e+00-7.4218e-01j,
#          -1.1626e+00+7.4398e-01j,  2.4846e-01-3.4550e+00j],
#         [ 1.1477e+01-1.0169e+01j,  2.8133e+02+6.3724e+02j,
#           2.0294e-01+1.5006e-01j, -4.8435e-01+1.5912e+00j]],
#        grad_fn=<SubBackward0>)

# %%
# Absolute values of differences
(Y_test_pred - Y_test).abs()
# Out:
# tensor([[5.0127e+00, 1.6531e+01, 1.1781e+00, 1.3090e+00],
#         [8.0043e-01, 5.3386e+01, 1.0332e+00, 3.9013e+00],
#         [5.9361e-01, 1.3609e+00, 1.3803e+00, 3.4639e+00],
#         [1.5334e+01, 6.9657e+02, 2.5240e-01, 1.6633e+00]],
#        grad_fn=<AbsBackward0>)
