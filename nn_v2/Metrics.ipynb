# %%
import numpy as np
import pandas as pd

# %%
metrics = pd.read_json("metrics.json")
cols = metrics.columns
ind = metrics.index
metrics = np.array(metrics)
metrics = pd.DataFrame(metrics.T, index=cols, columns=ind)
metrics
# Out:
#                   Train Loss Training Time       Test R2  \
# N256_L2_ReLU        0.000907       10.5201     -1.224281
# N256_L2_LeakyReLU   0.000813     10.992651     -0.897217
# N256_L2_Sigmoid     0.001454      14.79773      0.344388
# N256_L2_Tanh        0.000267     13.798098      0.589595
# N256_L2_None        0.006105     12.571667    -22.066761
# N256_L3_ReLU        0.000897     18.184468      0.352729
# N256_L3_LeakyReLU   0.000871     28.369516      0.302419
# N256_L3_Sigmoid     0.001606     19.977553      0.266775
# N256_L3_Tanh        0.000552     18.646645      0.545359
# N256_L3_None        0.065926     18.126102    -105.89389
# N256_L4_ReLU        0.000854     27.966158      0.322702
# N256_L4_LeakyReLU   0.000709     26.950047      0.404794
# N256_L4_Sigmoid     0.004474     27.187718      0.126946
# N256_L4_Tanh        0.000623     26.902307      0.475269
# N256_L4_None        0.405862     25.496501   -501.022339
# ...

# %%
metrics.sort_values(by='Test R2', ascending = False)
# Out:
#                   Train Loss Training Time       Test R2  \
# N256_L2_Tanh        0.000267     13.798098      0.589595
# N256_L3_Tanh        0.000552     18.646645      0.545359
# N256_L4_Tanh        0.000623     26.902307      0.475269
# N512_L3_Tanh        0.000145     78.776018      0.455143
# N256_L5_Tanh        0.000661     42.818507      0.436757
# N256_L4_LeakyReLU   0.000709     26.950047      0.404794
# N512_L4_Tanh        0.000172    115.060462      0.386142
# N256_L5_ReLU        0.001157     38.759218      0.352755
# N256_L3_ReLU        0.000897     18.184468      0.352729
# N256_L5_LeakyReLU    0.00129     37.408473      0.349871
# N512_L5_Tanh        0.000228    164.092452      0.349411
# N256_L2_Sigmoid     0.001454      14.79773      0.344388
# N256_L4_ReLU        0.000854     27.966158      0.322702
# N512_L4_ReLU        0.000344    139.850381      0.303109
# N256_L3_LeakyReLU   0.000871     28.369516      0.302419
# ...
